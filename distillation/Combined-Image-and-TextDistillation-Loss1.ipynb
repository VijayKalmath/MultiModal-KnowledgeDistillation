# %%
import os
import sys
import numpy as np
import torch

from datetime import datetime
from typing import Tuple
from torch import nn
from torch.nn import Module
import torch.nn.functional as F
from torch.nn import KLDivLoss, CrossEntropyLoss, CosineEmbeddingLoss, MSELoss
from torch.optim import Adam, SGD
from torch.optim.lr_scheduler import ReduceLROnPlateau

# %%
loss_name = "loss1"

# %% [markdown]
# ### Loading Teacher models

# %%
import clip

model_name = "ViT-B/32"

# model is the torch model.
# preprocess function is for image preprocessing.

model, preprocess = clip.load(model_name)

# Get only the visual model
visual_teacher_model = model.visual
text_teacher_model = model.transformer


input_resolution = model.visual.input_resolution

# %%
model.vocab_size
# Out:
# 49408

# %% [markdown]
# ### Instantiating Student models
#
# [VisionTransformer](https://github.com/openai/CLIP/blob/d50d76daa670286dd6cacf3bcd80b5e4823fc8e1/clip/model.py#L206)
# [Transformer](https://github.com/openai/CLIP/blob/d50d76daa670286dd6cacf3bcd80b5e4823fc8e1/clip/model.py#L195)

# %%
from clip.model import Transformer, VisionTransformer
from clip.model import convert_weights  # Make them float16

# Set Student Configuration

patch_size = 32
width = 384
layers = 6
heads = 12
output_dim = 512

visual_student_model = VisionTransformer(
    input_resolution=input_resolution,
    patch_size=patch_size,
    width=width,
    layers=layers,
    heads=heads,
    output_dim=output_dim,
)

width = 512
layers = 6
heads = 8


def build_attention_mask():
    context_length = 77
    mask = torch.empty(context_length, context_length)
    mask.fill_(float("-inf"))
    mask.triu_(1)  # zero out the lower diagonal
    return mask


text_student_model = Transformer(
    width=width, layers=layers, heads=heads, attn_mask=build_attention_mask()
)


convert_weights(visual_student_model)
convert_weights(text_student_model)

# %%
def encode_text(transformer, text):

    x = model.token_embedding(text).type(model.dtype)  # [batch_size, n_ctx, d_model]

    x = x + model.positional_embedding.type(model.dtype)
    x = x.permute(1, 0, 2)  # NLD -> LND

    x = transformer(x)

    x = x.permute(1, 0, 2)  # LND -> NLD
    x = model.ln_final(x).type(model.dtype)

    # x.shape = [batch_size, n_ctx, transformer.width]
    # take features from the eot embedding (eot_token is the highest number in each sequence)
    x = x[torch.arange(x.shape[0]), text.argmax(dim=-1)] @ model.text_projection

    return x

# %%
class ProjectionHead(nn.Module):
    def __init__(self, embedding_dim=512, projection_dim=512, dropout=0.2):
        super().__init__()
        self.projection = nn.Linear(embedding_dim, projection_dim)
        self.gelu = nn.GELU()
        self.fc = nn.Linear(projection_dim, projection_dim)
        self.dropout = nn.Dropout(dropout)
        self.layer_norm = nn.LayerNorm(projection_dim)

    def forward(self, x):
        projected = self.projection(x)
        x = self.gelu(projected)
        x = self.fc(x)
        x = self.dropout(x)
        x = x + projected
        x = self.layer_norm(x)
        return x

# %% [markdown]
# ### Load the WIT Dataset

# %%
# from concurrent.futures import ThreadPoolExecutor
# from functools import partial
# import io
# import urllib

# import PIL.Image

# from datasets import load_dataset
# from datasets.utils.file_utils import get_datasets_user_agent


# def fetch_single_image(image_url, timeout=None, retries=0):
#     for _ in range(retries + 1):
#         try:
#             request = urllib.request.Request(
#                 image_url,
#                 data=None,
#                 headers={"user-agent": get_datasets_user_agent()},
#             )
#             with urllib.request.urlopen(request, timeout=timeout) as req:
#                 image = PIL.Image.open(io.BytesIO(req.read()))
#             break
#         except Exception:
#             image = None
#     return image


# def fetch_images(batch, num_threads, timeout=None, retries=0):
#     fetch_single_image_with_args = partial(
#         fetch_single_image, timeout=timeout, retries=retries
#     )
#     with ThreadPoolExecutor(max_workers=num_threads) as executor:
#         batch["image"] = list(
#             executor.map(fetch_single_image_with_args, batch["image_url"])
#         )
#     return batch


# num_threads = 20
# dset = load_dataset("conceptual_captions",split='train[:10000]')
# dset = dset.remove_columns("image_url")

# dset = dset.filter(lambda example: len(example["caption"]) < 75)

# dset = dset.map(
#     fetch_images, batched=True, batch_size=100, fn_kwargs={"num_threads": num_threads}
# )

# dset = dset.filter(lambda example : example["image"] is not None)

# def transform_func(examples):
#     examples["image"] = [preprocess(img) for img in examples["image"]]
#     return examples

# dset = dset.with_transform(transform_func)

# %% [markdown]
# ### Convert Dataset into Torch Dataloader

# %%
from torch.utils.data import DataLoader
from datasets import load_from_disk

dset = load_from_disk("./data/processed")


def transform_func(examples):
    examples["image"] = [preprocess(img) for img in examples["image"]]
    return examples


dset = dset.with_transform(transform_func)

train_dataloader = DataLoader(dset, batch_size=16, shuffle=True, num_workers=8)

# %%
dset
# Out:
# Dataset({
#     features: ['caption', 'image'],
#     num_rows: 7012
# })

# %%
class DistillationTrainer:
    def __init__(self, *args, **kwargs):

        self.visual_teacher = visual_teacher_model
        self.text_teacher = text_teacher_model

        self.visual_student = visual_student_model
        self.text_student = text_student_model

        self.image_projection = ProjectionHead().half()
        self.text_projection = ProjectionHead().half()
        self.temperature = 1

        self.train_dataloader = train_dataloader

        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

        self.visual_teacher = self.visual_teacher.to(self.device)
        self.text_teacher = self.text_teacher.to(self.device)
        self.visual_student = self.visual_student.to(self.device)
        self.text_student = self.text_student.to(self.device)
        self.image_projection = self.image_projection.to(self.device)
        self.text_projection = self.text_projection.to(self.device)

        self.visual_teacher.eval()
        self.text_teacher.eval()

        self.epochs = 30
        self.start_epoch = 1

        # set up optimizer
        self.optimizer = SGD(
            list(self.visual_student.parameters())
            + list(self.text_student.parameters()),
            lr=0.001,
        )

    def compute_loss(self, images, texts, return_outputs=False):
        texts = clip.tokenize(texts)

        texts = texts.to(self.device)

        images = images.to(self.device).half()

        visual_outputs_student = self.visual_student(images)
        text_outputs_student = encode_text(self.text_student, texts)

        # compute teacher output
        with torch.no_grad():
            visual_outputs_teacher = self.visual_teacher(images)
            text_outputs_teacher = model.encode_text(texts)

        # assert size
        assert visual_outputs_student.size() == visual_outputs_teacher.size()
        assert text_outputs_student.size() == text_outputs_teacher.size()

        # KL Divergence Loss
        kl_loss = KLDivLoss(reduction="batchmean", log_target=True)

        text_kl_loss = kl_loss(
            F.log_softmax(text_outputs_student), F.log_softmax(text_outputs_teacher)
        )

        image_kl_loss = kl_loss(
            F.log_softmax(visual_outputs_student), F.log_softmax(visual_outputs_teacher)
        )

        # Push visual_outputs_student and text_outputs_student closer

        image_embeddings = self.image_projection(visual_outputs_student)
        text_embeddings = self.text_projection(text_outputs_student)
        logits = (text_embeddings @ image_embeddings.T) / self.temperature

        images_similarity = image_embeddings @ image_embeddings.T
        texts_similarity = text_embeddings @ text_embeddings.T

        targets = F.softmax(
            (images_similarity + texts_similarity) / 2 * self.temperature, dim=-1
        )

        texts_loss = self.cross_entropy(logits, targets, reduction="none")
        images_loss = self.cross_entropy(logits.T, targets.T, reduction="none")
        con_loss = (images_loss + texts_loss) / 2.0
        con_loss = con_loss.mean()

        loss = (text_kl_loss + image_kl_loss + con_loss) / 3

        return loss

    def cross_entropy(self, preds, targets, reduction="none"):
        log_softmax = nn.LogSoftmax(dim=-1)
        loss = (-targets * log_softmax(preds)).sum(1)
        if reduction == "none":
            return loss
        elif reduction == "mean":
            return loss.mean()

    def train(self):
        for epoch in range(self.start_epoch, self.epochs + 1):
            print(f"Starting Epoch {epoch} ------------------------------------------")
            loss_value = self._train_epoch(epoch)
            print(f"Combined Loss Value after {epoch} Epoch is {loss_value}")

    def _train_epoch(self, epoch):
        loss_value = 0
        for batch_idx, data in enumerate(self.train_dataloader):

            self.optimizer.zero_grad()

            texts = data["caption"]
            images = data["image"]

            loss = self.compute_loss(images, texts)

            loss_value += loss

            loss.backward()

            self.optimizer.step()

            if batch_idx % 100 == 0:
                print(
                    f"Loss after {batch_idx}/{len(self.train_dataloader)} Batch is {loss_value/(batch_idx+1)} "
                )

        return loss_value.detach().cpu().numpy() / len(self.train_dataloader)

# %%
Trainer = DistillationTrainer(
    visual_teacher_model=visual_teacher_model,
    text_teacher_model=text_teacher_model,
    text_student_model=text_student_model,
    visual_student_model=visual_student_model,
    train_dataloader=train_dataloader,
)

# %%
Trainer.train()
# Out:
# Starting Epoch 1 ------------------------------------------
# /home/ecbm4040/envTF24/lib/python3.6/site-packages/ipykernel_launcher.py:59: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# /home/ecbm4040/envTF24/lib/python3.6/site-packages/ipykernel_launcher.py:61: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# Loss after 0/439 Batch is 3.375
# Loss after 100/439 Batch is 2.974609375
# Loss after 200/439 Batch is 2.54296875
# Loss after 300/439 Batch is 2.322265625
# Loss after 400/439 Batch is 2.154296875
# Combined Loss Value after 1 Epoch is 2.0979498861047836
# Starting Epoch 2 ------------------------------------------
# Loss after 0/439 Batch is 1.5810546875
# Loss after 100/439 Batch is 1.5849609375
# Loss after 200/439 Batch is 1.5576171875
# Loss after 300/439 Batch is 1.5244140625
# Loss after 400/439 Batch is 1.5126953125
# Combined Loss Value after 2 Epoch is 1.510250569476082
# Starting Epoch 3 ------------------------------------------
# Loss after 0/439 Batch is 1.2880859375
# Loss after 100/439 Batch is 1.359375
# Loss after 200/439 Batch is 1.3544921875
# Loss after 300/439 Batch is 1.34375
# Loss after 400/439 Batch is 1.3330078125
# Combined Loss Value after 3 Epoch is 1.3371298405466971
# Starting Epoch 4 ------------------------------------------
# Loss after 0/439 Batch is 1.3251953125
# Loss after 100/439 Batch is 1.2744140625
# Loss after 200/439 Batch is 1.2705078125
# Loss after 300/439 Batch is 1.265625
# Loss after 400/439 Batch is 1.2626953125
# Combined Loss Value after 4 Epoch is 1.2574031890660593
# Starting Epoch 5 ------------------------------------------
# Loss after 0/439 Batch is 1.2587890625
# Loss after 100/439 Batch is 1.2255859375
# Loss after 200/439 Batch is 1.228515625
# Loss after 300/439 Batch is 1.23046875
# Loss after 400/439 Batch is 1.23046875
# Combined Loss Value after 5 Epoch is 1.2209567198177675
# Starting Epoch 6 ------------------------------------------
# Loss after 0/439 Batch is 1.2294921875
# Loss after 100/439 Batch is 1.17578125
# Loss after 200/439 Batch is 1.1826171875
# Loss after 300/439 Batch is 1.1826171875
# Loss after 400/439 Batch is 1.193359375
# Combined Loss Value after 6 Epoch is 1.1879271070615034
# Starting Epoch 7 ------------------------------------------
# Loss after 0/439 Batch is 1.2158203125
# Loss after 100/439 Batch is 1.1572265625
# Loss after 200/439 Batch is 1.1552734375
# Loss after 300/439 Batch is 1.1572265625
# Loss after 400/439 Batch is 1.1552734375
# Combined Loss Value after 7 Epoch is 1.1571753986332574
# Starting Epoch 8 ------------------------------------------
# Loss after 0/439 Batch is 1.2109375
# Loss after 100/439 Batch is 1.1484375
# Loss after 200/439 Batch is 1.1396484375
# Loss after 300/439 Batch is 1.1279296875
# Loss after 400/439 Batch is 1.123046875
# Combined Loss Value after 8 Epoch is 1.117881548974943
# Starting Epoch 9 ------------------------------------------
# Loss after 0/439 Batch is 1.12890625
# Loss after 100/439 Batch is 1.1083984375
# Loss after 200/439 Batch is 1.1103515625
# Loss after 300/439 Batch is 1.109375
# Loss after 400/439 Batch is 1.1103515625
# Combined Loss Value after 9 Epoch is 1.1082004555808656
# Starting Epoch 10 ------------------------------------------
# Loss after 0/439 Batch is 1.1005859375
# Loss after 100/439 Batch is 1.0908203125
# Loss after 200/439 Batch is 1.0908203125
# Loss after 300/439 Batch is 1.0830078125
# Loss after 400/439 Batch is 1.0771484375
# Combined Loss Value after 10 Epoch is 1.0785876993166288
# Starting Epoch 11 ------------------------------------------
# Loss after 0/439 Batch is 1.046875
# Loss after 100/439 Batch is 1.0849609375
# Loss after 200/439 Batch is 1.08984375
# Loss after 300/439 Batch is 1.0751953125
# Loss after 400/439 Batch is 1.068359375
# Combined Loss Value after 11 Epoch is 1.0649202733485195
# Starting Epoch 12 ------------------------------------------
# Loss after 0/439 Batch is 1.0439453125
# Loss after 100/439 Batch is 1.0654296875
# Loss after 200/439 Batch is 1.06640625
# Loss after 300/439 Batch is 1.0615234375
# Loss after 400/439 Batch is 1.0546875
# Combined Loss Value after 12 Epoch is 1.0518223234624147
# Starting Epoch 13 ------------------------------------------
# Loss after 0/439 Batch is 1.0634765625
# Loss after 100/439 Batch is 1.05078125
# Loss after 200/439 Batch is 1.044921875
# Loss after 300/439 Batch is 1.0400390625
# Loss after 400/439 Batch is 1.041015625
# Combined Loss Value after 13 Epoch is 1.0387243735763099
# Starting Epoch 14 ------------------------------------------
# Loss after 0/439 Batch is 0.98486328125
# Loss after 100/439 Batch is 1.04296875
# Loss after 200/439 Batch is 1.0419921875
# Loss after 300/439 Batch is 1.041015625
# Loss after 400/439 Batch is 1.033203125
# Combined Loss Value after 14 Epoch is 1.030751708428246
# Starting Epoch 15 ------------------------------------------
# Loss after 0/439 Batch is 1.072265625
# Loss after 100/439 Batch is 1.0322265625
# Loss after 200/439 Batch is 1.0283203125
# Loss after 300/439 Batch is 1.0283203125
# Loss after 400/439 Batch is 1.025390625
# Combined Loss Value after 15 Epoch is 1.0239179954441913
# Starting Epoch 16 ------------------------------------------
# Loss after 0/439 Batch is 1.140625
# Loss after 100/439 Batch is 1.0107421875
# Loss after 200/439 Batch is 1.0126953125
# Loss after 300/439 Batch is 1.015625
# Loss after 400/439 Batch is 1.009765625
# Combined Loss Value after 16 Epoch is 1.0096810933940774
# Starting Epoch 17 ------------------------------------------
# Loss after 0/439 Batch is 1.0703125
# Loss after 100/439 Batch is 1.017578125
# Loss after 200/439 Batch is 1.0146484375
# Loss after 300/439 Batch is 1.0126953125
# Loss after 400/439 Batch is 1.0107421875
# Combined Loss Value after 17 Epoch is 1.0091116173120729
# Starting Epoch 18 ------------------------------------------
# Loss after 0/439 Batch is 0.90966796875
# Loss after 100/439 Batch is 1.001953125
# Loss after 200/439 Batch is 1.0009765625
# Loss after 300/439 Batch is 0.9990234375
# Loss after 400/439 Batch is 0.99755859375
# Combined Loss Value after 18 Epoch is 0.9965831435079726
# Starting Epoch 19 ------------------------------------------
# Loss after 0/439 Batch is 0.93310546875
# Loss after 100/439 Batch is 0.98193359375
# Loss after 200/439 Batch is 0.98583984375
# Loss after 300/439 Batch is 0.990234375
# Loss after 400/439 Batch is 0.98876953125
# Combined Loss Value after 19 Epoch is 0.9874715261958997
# Starting Epoch 20 ------------------------------------------
# Loss after 0/439 Batch is 1.02734375
# Loss after 100/439 Batch is 0.98291015625
# Loss after 200/439 Batch is 0.984375
# Loss after 300/439 Batch is 0.98193359375
# Loss after 400/439 Batch is 0.986328125
# Combined Loss Value after 20 Epoch is 0.9857630979498861
# Starting Epoch 21 ------------------------------------------
# Loss after 0/439 Batch is 1.0185546875
# Loss after 100/439 Batch is 0.9775390625
# Loss after 200/439 Batch is 0.97705078125
# Loss after 300/439 Batch is 0.9716796875
# Loss after 400/439 Batch is 0.97509765625
# Combined Loss Value after 21 Epoch is 0.9720956719817767
# Starting Epoch 22 ------------------------------------------
# Loss after 0/439 Batch is 1.005859375
# Loss after 100/439 Batch is 0.97900390625
# Loss after 200/439 Batch is 0.966796875
# Loss after 300/439 Batch is 0.970703125
# Loss after 400/439 Batch is 0.97216796875
# Combined Loss Value after 22 Epoch is 0.9709567198177677
# Starting Epoch 23 ------------------------------------------
# Loss after 0/439 Batch is 1.0673828125
# Loss after 100/439 Batch is 0.9482421875
# Loss after 200/439 Batch is 0.95068359375
# Loss after 300/439 Batch is 0.9560546875
# Loss after 400/439 Batch is 0.9599609375
# Combined Loss Value after 23 Epoch is 0.9584282460136674
# Starting Epoch 24 ------------------------------------------
# Loss after 0/439 Batch is 0.95458984375
# Loss after 100/439 Batch is 0.94482421875
# Loss after 200/439 Batch is 0.95068359375
# Loss after 300/439 Batch is 0.95361328125
# Loss after 400/439 Batch is 0.9482421875
# Combined Loss Value after 24 Epoch is 0.9481776765375854
# Starting Epoch 25 ------------------------------------------
# Loss after 0/439 Batch is 0.99365234375
# Loss after 100/439 Batch is 0.9375
# Loss after 200/439 Batch is 0.93603515625
# Loss after 300/439 Batch is 0.9404296875
# Loss after 400/439 Batch is 0.9453125
# Combined Loss Value after 25 Epoch is 0.9470387243735763
# Starting Epoch 26 ------------------------------------------
# Loss after 0/439 Batch is 0.8984375
# Loss after 100/439 Batch is 0.9326171875
# Loss after 200/439 Batch is 0.93359375
# Loss after 300/439 Batch is 0.9345703125
# Loss after 400/439 Batch is 0.9375
# Combined Loss Value after 26 Epoch is 0.9384965831435079
# Starting Epoch 27 ------------------------------------------
# Loss after 0/439 Batch is 0.97900390625
# Loss after 100/439 Batch is 0.927734375
# Loss after 200/439 Batch is 0.927734375
# Loss after 300/439 Batch is 0.92626953125
# Loss after 400/439 Batch is 0.923828125
# Combined Loss Value after 27 Epoch is 0.9219817767653758
# Starting Epoch 28 ------------------------------------------
# Loss after 0/439 Batch is 1.1669921875
# Loss after 100/439 Batch is 0.93310546875
# Loss after 200/439 Batch is 0.92431640625
# Loss after 300/439 Batch is 0.9267578125
# Loss after 400/439 Batch is 0.92578125
# Combined Loss Value after 28 Epoch is 0.9242596810933941
# Starting Epoch 29 ------------------------------------------
# Loss after 0/439 Batch is 0.89599609375
# Loss after 100/439 Batch is 0.900390625
# Loss after 200/439 Batch is 0.90625
# Loss after 300/439 Batch is 0.9111328125
# Loss after 400/439 Batch is 0.91064453125
# Combined Loss Value after 29 Epoch is 0.9123006833712984
# Starting Epoch 30 ------------------------------------------
# Loss after 0/439 Batch is 0.87939453125
# Loss after 100/439 Batch is 0.912109375
# Loss after 200/439 Batch is 0.904296875
# Loss after 300/439 Batch is 0.904296875
# Loss after 400/439 Batch is 0.90087890625
# Combined Loss Value after 30 Epoch is 0.8980637813211845

# %%
from datetime import datetime

format_data = "date_%d_%m_%y_time_%H_%M_%S"
timestamp = datetime.strftime(datetime.now(), format_data)

torch.save(
    Trainer.visual_student.state_dict(),
    f"results/{timestamp}_{loss_name}_CombinedVisual_DistilledModel.pt",
)
torch.save(
    Trainer.text_student.state_dict(),
    f"results/{timestamp}_{loss_name}_CombinedText_DistilledModel.pt",
)
